# %%
# !git clone https://github.com/Masesee/Computer-Vision-CGIAR.git
# Out:
# Cloning into 'Computer-Vision-CGIAR'...
# remote: Enumerating objects: 237, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 237 (delta 36), reused 0 (delta 0), pack-reused 173 (from 2)
# Receiving objects: 100% (237/237), 130.09 KiB | 9.29 MiB/s, done.
# Resolving deltas: 100% (120/120), done.

# %%
# %cd Computer-Vision-CGIAR
# Out:
# /kaggle/working/Computer-Vision-CGIAR

# %%
# !git pull origin working
# !git reset --hard origin/working
# Out:
# From https://github.com/Masesee/Computer-Vision-CGIAR
#  * branch            working    -> FETCH_HEAD
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.
# HEAD is now at 39881f6 Update train.py

# %%
# !pip install -r /kaggle/working/Computer-Vision-CGIAR/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 18.2 MB/s eta 0:00:00
# ...

# %%
import sys
sys.path.append('/kaggle/working/Computer-Vision-CGIAR')

# %%
# rm -rf /kaggle/working/Computer-Vision-CGIAR/checkpoints

# %% [markdown]
# # Model training.

# %%
# !python /kaggle/working/Computer-Vision-CGIAR/train.py --model resnet
# Out:
# 2025-03-17 13:58:07.791548: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-17 13:58:08.046753: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-17 13:58:08.136978: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python /kaggle/working/Computer-Vision-CGIAR/train.py --model efficientnet
# Out:
# 2025-03-17 14:10:39.982413: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-17 14:10:40.010399: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-17 14:10:40.019307: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python /kaggle/working/Computer-Vision-CGIAR/train.py --model mobilenet
# Out:
# 2025-03-17 14:23:42.965407: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-17 14:23:42.985251: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-17 14:23:42.991307: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python /kaggle/working/Computer-Vision-CGIAR/train.py --model vit
# Out:
# 2025-03-17 14:28:46.175623: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-17 14:28:46.195532: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-17 14:28:46.201552: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python /kaggle/working/Computer-Vision-CGIAR/train.py --model vgg
# Out:
# 2025-03-17 14:45:10.907973: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-17 14:45:10.928378: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-17 14:45:10.934499: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# usage: train.py [-h] --model {resnet,efficientnet,mobilenet,vit}
# train.py: error: argument --model: invalid choice: 'vgg' (choose from 'resnet', 'efficientnet', 'mobilenet', 'vit')

# %%
# !python /kaggle/working/Computer-Vision-CGIAR/train.py --model yolo
# Out:
# 2025-03-17 14:45:19.814419: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-17 14:45:19.848401: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-17 14:45:19.858490: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# usage: train.py [-h] --model {resnet,efficientnet,mobilenet,vit}
# train.py: error: argument --model: invalid choice: 'yolo' (choose from 'resnet', 'efficientnet', 'mobilenet', 'vit')

# %% [markdown]
# # Evaluation

# %%
# !python /kaggle/working/Computer-Vision-CGIAR/evaluate_models.py
# Out:
# 2025-03-17 14:45:29.815927: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-17 14:45:29.843708: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-17 14:45:29.850983: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
import IPython.display as display
from pathlib import Path

# Define the directory where the images are saved
image_dir = Path("/kaggle/working/Computer-Vision-CGIAR")

# List of possible saved plots
image_files = [
    "validation_mae.png",
    "validation_loss.png",
    "regression_plot_resnet.png",
    "regression_plot_efficientnet.png",
    "regression_plot_mobilenet.png",
]

#     
#     "regression_plot_vit.png",
# Display each saved image
for img_name in image_files:
    img_path = image_dir / img_name
    if img_path.exists():
        print(f"Displaying: {img_name}")
        display.display(display.Image(str(img_path)))
    else:
        print(f"Image not found: {img_name}")
# Out:
# Image not found: validation_mae.png
# Image not found: validation_loss.png
# Displaying: regression_plot_resnet.png
# Displaying: regression_plot_efficientnet.png
# Displaying: regression_plot_mobilenet.png

# %% [markdown]
# # Predicting on test data

# %%
# !python /kaggle/working/Computer-Vision-CGIAR/predict.py --model /kaggle/working/Computer-Vision-CGIAR/vit_model.keras  --output /kaggle/working/v5_v2_sub4.csv
# Out:
# 2025-03-17 14:48:00.188678: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-17 14:48:00.210069: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-17 14:48:00.216596: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading specified model: /kaggle/working/Computer-Vision-CGIAR/vit_model.keras
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python /kaggle/working/Computer-Vision-CGIAR/predict_vit.py --model /kaggle/working/Computer-Vision-CGIAR/vit_model.keras  --output /kaggle/working/v5_v2_sub4.csv
# Out:
# 2025-03-17 14:50:17.595565: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-17 14:50:17.618384: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-17 14:50:17.625102: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading ViT model from /kaggle/working/Computer-Vision-CGIAR/vit_model.keras with custom layers...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
